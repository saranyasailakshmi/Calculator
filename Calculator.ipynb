# %%
import math
print("Select an Operation To Perform")
print("1. ADD")
print("2. SUBTRACT")
print("3. MULTIPLY")
print("4. DIVIDE")
print("5. EXACTVALUE")
print("6. SQUARE")
print("7. CUBE")
print("8. SQUARE ROOT")
print("9. CUBE ROOT")
print("10. SINE")
print("11. COS")
print("12. TANGENT")
print("13. COT")
print("14. SECENT")
print("15. COSECENT")

operation = input()

if operation == "1":
    num1 =input ("Enter a First number:")    
    num2 =input("Enter a Second number:")
    print("The Sum is:"+str(int(num1) + int(num2)))
elif operation == "2":
    num1 =input ("Enter a First Number")
    num2 =input ("Enter a Second Number")
    print("The Differnce is:"+ str(int(num1) - int(num2)))
elif operation == "3":
    num1 =input ("Enter a First Number")
    num2 =input ("Enter a Second Number")
    print("The Product is:"+ str(int(num1) * int(num2)))
elif operation =="4":
    num1 =input ("Enter a First Number")
    num2 =input ("Enter a Second Number")
    print("The Quotient is:"+str(int(num1) / int(num2)))
elif operation =="5":
    num1 =input ("Enter a First Number")
    num2 =input ("Enter a Second Number")
    print("The Quotient is:"+str(int(num1) // int(num2)))
elif operation =="6":
    num1 = input("Enter the Number:")
    print("The Square of Number Is:"+str(int(num1) ** 2))
elif operation =="7":
    num1 = input("Enter a Valid Number:")
    print("The Cube of Number Is:"+str(int(num1)**3))
elif operation =="8":
    num1 = input("Enter a Number:")
    print("The SquareRoot is"+str(math.sqrt(int(num1))))
elif operation =="9":
    num1=input("Enter the Valid Number:")
    print("The Cube Root is:"+str(int(num1)** (1/3)))
elif operation == "10":
    angle = input("Enter the angle in degrees: ")
    print("The Sine is:"+str(math.sin(math.radians(int(angle)))))
elif operation == "11":
    angle = input("Enter the angle in degrees:")
    print("The Cosine Value Is:"+str(math.cos(math.radians(int(angle)))))
elif operation == "12":
    angle = input("Enter the angle in degrees:")
    print("The Tangent Value Is:"+str(math.tan(math.radians(int(angle)))))
elif operation == "13":
    angle = input("Enter the angle in degrees: ")
    print("The Cot is:"+str(1/math.tan(math.radians(int(angle)))))
elif operation == "14":
    angle = input("Enter the angle in degrees:")
    print("The Secent Value Is:"+str(1/math.cos(math.radians(int(angle)))))
elif operation == "15":
    angle = input("Enter the angle in degrees: ")
    print("The Cosecant is:"+str(1/math.sin(math.radians(int(angle)))))
else:
    print("Invalid Operation Selected")
# Out:
# Select an Operation To Perform
# 1. ADD
# 2. SUBTRACT
# 3. MULTIPLY
# 4. DIVIDE
# 5. EXACTVALUE
# 6. SQUARE
# 7. CUBE
# 8. SQUARE ROOT
# 9. CUBE ROOT
# 10. SINE
# 11. COS
# 12. TANGENT
# 13. COT
# 14. SECENT
# 15. COSECENT
# 13
# Enter the angle in degrees: 45
# The Cot is:1.0000000000000002
